# %% [markdown]
# ## Perfil dos "Novos Clientes"
# ---
#  Analisar as características dos clientes classificados como "Novo Cliente" para entender melhor o perfil de quem a empresa está atraindo.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df_clientes = pd.read_excel('mercado.xlsx')
df_clientes.head()
# Out:
#   Centro de Responsabilidade  Cod centro  Cod conta 1º nível  \
# 0                    Moderna       10100                   2
# 1                    Moderna       10100                   2
# 2                    Moderna       10100                   2
# 3                    Moderna       10100                   2
# 4                    Moderna       10100                   2
#
#   Nome conta 2º nível  Cod conta 2º nível   Nome conta 3º nível  \
# 0  Receitas Correntes                  21  Receitas de serviços
# 1  Receitas Correntes                  21  Receitas de serviços
# 2  Receitas Correntes                  21  Receitas de serviços
# 3  Receitas Correntes                  21  Receitas de serviços
# 4  Receitas Correntes                  21  Receitas de serviços
#
#    Cod conta 3º nível Motivo do contato               Vendedor  \
# 0                 211        Prospecção  Julio César (Toronto)
# 1                 211           Demanda   Victor (Atlético-MG)
# 2                 211           Demanda  Julio César (Toronto)
# 3                 211        Prospecção  Julio César (Toronto)
# 4                 211           Demanda   Victor (Atlético-MG)
#
#   Data da Admissão  ...      Mês  nº Mês Receitas de Serviço (contratos)  \
# 0       2014-07-03  ...  JANEIRO       1                        55609.64
# 1       2005-07-03  ...  JANEIRO       1                               -
# 2       2014-07-03  ...  JANEIRO       1                       142996.22
# 3       2014-07-03  ...  JANEIRO       1                        54047.04
# 4       2004-07-03  ...  JANEIRO       1                       252219.51
#
#        Foma de Pagamento  Cadastro de Reclamação Reclamação Cadastrada  \
# 0  Tranferencia bancária                     Sim           Atendimento
# 1                    NaN                       -                   NaN
# 2                Espécie                     Sim      Prazo de Entrega
# 3                    PIX                     NaN                   NaN
# 4  Tranferencia bancária                     NaN                   NaN
#
#   Retorno à reclamação Satifação com o Produto  NPS  Tipo de Cliente
# 0                  Sim                     Não    4     Novo Cliente
# 1                  NaN                     Sim    2              NaN
# 2                  Sim                       -    -              NaN
# 3                  NaN                     Sim    8     Novo Cliente
# 4                  NaN                     Sim    7              NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Tabela de novos clientes

# %%
novos_clientes = df_clientes[df_clientes['Tipo de Cliente'] == 'Novo Cliente']
novos_clientes.head()
# Out:
#   Centro de Responsabilidade  Cod centro  Cod conta 1º nível  \
# 0                    Moderna       10100                   2
# 3                    Moderna       10100                   2
# 5                  Progresso       10112                   2
# 6                  Progresso       10112                   2
# 7                   Itatiaia       10110                   2
#
#   Nome conta 2º nível  Cod conta 2º nível   Nome conta 3º nível  \
# 0  Receitas Correntes                  21  Receitas de serviços
# 3  Receitas Correntes                  21  Receitas de serviços
# 5  Receitas Correntes                  21  Receitas de serviços
# 6  Receitas Correntes                  21  Receitas de serviços
# 7  Receitas Correntes                  21  Receitas de serviços
#
#    Cod conta 3º nível Motivo do contato                 Vendedor  \
# 0                 211        Prospecção    Julio César (Toronto)
# 3                 211        Prospecção    Julio César (Toronto)
# 5                 211        Prospecção  Aurélio de Lira Tavares
# 6                 211        Prospecção               Café Filho
# 7                 211        Prospecção      Píndaro do Carvalho
#
#   Data da Admissão  ...      Mês  nº Mês Receitas de Serviço (contratos)  \
# 0       2014-07-03  ...  JANEIRO       1                        55609.64
# 3       2014-07-03  ...  JANEIRO       1                        54047.04
# 5       2015-09-11  ...  JANEIRO       1                               -
# 6       2004-07-03  ...  JANEIRO       1                       243496.34
# 7       2017-09-03  ...  JANEIRO       1                        11013.39
#
#        Foma de Pagamento  Cadastro de Reclamação Reclamação Cadastrada  \
# 0  Tranferencia bancária                     Sim           Atendimento
# 3                    PIX                     NaN                   NaN
# 5                    NaN                     Sim      Prazo de Entrega
# 6  Tranferencia bancária                     NaN                   NaN
# 7  Tranferencia bancária                     NaN                   NaN
#
#   Retorno à reclamação Satifação com o Produto  NPS  Tipo de Cliente
# 0                  Sim                     Não    4     Novo Cliente
# 3                  NaN                     Sim    8     Novo Cliente
# 5                  Sim                       -    -     Novo Cliente
# 6                  NaN                     Sim    4     Novo Cliente
# 7                  NaN                     Sim    3     Novo Cliente
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Distribuição de Novos Clientes por Centro de Responsabilidade
# ---
# Analisar de quais centros (ou regiões) vêm os novos clientes para entender
# quais localidades estão trazendo mais clientes novos.

# %%
centros = novos_clientes['Centro de Responsabilidade'].value_counts()
centros.plot(kind='bar', color='skyblue', edgecolor = 'black')
plt.title("Novos clientes por Centro de Responsabilidade")
plt.xlabel("Centro")
plt.ylabel("Quantidade")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
plt.savefig('graficos/novos_clientes_por_centro.png')

# %% [markdown]
# ### Distribuição de novos clientes por vendedor
# ---
# Entender o percentual de novos clientes que cada vendedor trouxe

# %%
vendedor = novos_clientes['Vendedor'].value_counts()

vendedor.plot(kind = 'pie',
    autopct='%1.1f%%',      # mostra os percentuais
    figsize=(14, 10),       
    labels=None   
    )
plt.title('Novos clientes por Vendedor', fontsize=16)
plt.ylabel('')

plt.legend(
    title='Novos clientes x Vendedores',
    labels=vendedor.index,
    bbox_to_anchor=(1.05, 1),
    loc='upper left'
)

plt.tight_layout()



plt.savefig('graficos/vendedor.png')
