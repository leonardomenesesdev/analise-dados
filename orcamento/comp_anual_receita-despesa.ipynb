# %% [markdown]
# ## Visualizar tudo

# %%
import pandas as pd

# O caminho correto para a sua estrutura
# Exemplo de como ficaria com um caminho absoluto
df = pd.read_excel(r'C:\Users\User\Desktop\analise-dados\orcamento\orcamento.xlsx')
df
# Out:
#     Centro de Responsabilidade  Cod centro Nome conta 1º nível  \
# 0                      Moderna       10112             Despesa
# 1                      Moderna       10112             Despesa
# 2                      Moderna       10112             Despesa
# 3                      Moderna       10112             Despesa
# 4                      Moderna       10112             Despesa
# ..                         ...         ...                 ...
# 698                    Colibri       10112             Despesa
# 699                    Colibri       10112             Despesa
# 700                    Colibri       10112             Despesa
# 701                    Colibri       10112             Receita
# 702                    Colibri       10112             Receita
#
#      Cod conta 1º nível  Nome conta 2º nível  Cod conta 2º nível  \
# 0                     1   Despesas Correntes                  11
# 1                     1   Despesas Correntes                  11
# ...
